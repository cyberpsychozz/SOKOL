# %% [markdown]
# # SOKOL RT-DETR-L training
#
# Edit `training/sokol_dataset.yaml` after the dataset finishes downloading, then run the cell below.

# %%
from pathlib import Path

script = Path('train_rtdetr_l.py') if Path('train_rtdetr_l.py').exists() else Path('training/train_rtdetr_l.py')
data = Path('sokol_dataset.yaml') if Path('sokol_dataset.yaml').exists() else Path('training/sokol_dataset.yaml')
cmd = f'python3 {script} --data {data} --epochs 100 --imgsz 640 --batch 8 --device 0'
# !{cmd}

# %%
# Export best checkpoint to ONNX after training if needed
from pathlib import Path

script = Path('train_rtdetr_l.py') if Path('train_rtdetr_l.py').exists() else Path('training/train_rtdetr_l.py')
data = Path('sokol_dataset.yaml') if Path('sokol_dataset.yaml').exists() else Path('training/sokol_dataset.yaml')
cmd = f'python3 {script} --data {data} --epochs 100 --imgsz 640 --batch 8 --device 0 --export'
# !{cmd}
